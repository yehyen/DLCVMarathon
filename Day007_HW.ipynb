# %% [markdown]
# # HTTP 靜態網頁架構說明
#
# * 認識靜態網頁的溝通架構與運作原理
# * HTML、CSS、JavaScript 在網頁中扮演的角色
# * 網頁中定位資料的方法

# %% [markdown]
# ## 作業目標
#
# 1. （簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？
# 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。

# %% [markdown]
# ### 1.（簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？

# %%
傳輸速度慢,資料包大(Http協議中包含輔助應用資訊)
如實時互動,伺服器效能壓力大。
資料傳輸安全性差。
發送請求到服務器，服務器沒有辦法完全校驗你和你的數據是否被修改。
# Out:
# '\nYour Reply\n'

# %% [markdown]
# ### 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。

# %%
Javascript是一種客戶端的指令碼語言主要應用於瀏覽器。
物件導向是基於prototype的，物件的繼承是由原型（也是物件）建立出來的。
沒有多執行緒的概念的，併發使用過使用事件驅動的方式來進行的，所有的JavaScript程式都執行在一個執行緒中。

Python則是中規中矩的基於class的繼承，並天然的支援多型。
Python通過thread包支援多執行緒。
# Out:
# '\nYour Reply\n'
